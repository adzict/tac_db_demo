# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('test_data.csv')

# %%
data.head()
# Out:
#   First Name Last Name Sex                      Email           Phone Number  \
# 0     Sherry    Spears   M          vhale@example.org  +1-869-537-4303x01334
# 1     Nicole    Campos   F   banksjasmine@example.org    (451)494-2569x29028
# 2   Jennifer     Lopez   M         mpayne@example.org       571-305-1592x124
# 3     Joseph   Herring   M  princemichael@example.org       001-212-859-7754
# 4    Barbara      Neal   F     nancypayne@example.com    (820)363-3058x66681
#
#                City  Current Ed Year Primary Supervisor Date of Birth  \
# 0     South Brandon                5    Sabrina Johnson    1924-09-07
# 1  New Samanthastad                1         Aaron Hahn    1999-12-10
# 2     North Jeffrey                2     Jeffrey Miller    1993-11-02
# 3   Hutchinsonhaven                1    Michelle Garner    1930-03-25
# 4  Christophershire                1  David Blankenship    1925-05-20
#
#                          Job Title
# 0                          Dentist
# ...
